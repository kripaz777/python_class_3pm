# %%
file = open('new_data.csv','x')
file.close()

# %%
import pandas as pd
df = pd.read_csv('new_data.csv')
df
# Out:
#    sn   name  age        add
# 0   1    Ram   45  Kathmandu
# 1   2  Shyam   56   Lalitpur
# 2   3   Hari   67  Bhaktapur
# 3   4   Sita   45      Jhapa
# 4   5  Nabin   34  Kathmandu
# 5   6  Sabin   45  Kathmandu

# %%
df.head(3)
# Out:
#    sn   name  age        add
# 0   1    Ram   45  Kathmandu
# 1   2  Shyam   56   Lalitpur
# 2   3   Hari   67  Bhaktapur

# %%
df.tail(3)
# Out:
#    sn   name  age        add
# 3   4   Sita   45      Jhapa
# 4   5  Nabin   34  Kathmandu
# 5   6  Sabin   45  Kathmandu

# %%
df
# Out:
#    sn   name  age        add
# 0   1    Ram   45  Kathmandu
# 1   2  Shyam   56   Lalitpur
# 2   3   Hari   67  Bhaktapur
# 3   4   Sita   45      Jhapa
# 4   5  Nabin   34  Kathmandu
# 5   6  Sabin   45  Kathmandu

# %%
import pandas as pd
df = pd.read_csv('new_data.csv',index_col = 'sn')
df
# Out:
#      name  age        add
# sn
# 1     Ram   45  Kathmandu
# 2   Shyam   56   Lalitpur
# 3    Hari   67  Bhaktapur
# 4    Sita   45      Jhapa
# 5   Nabin   34  Kathmandu
# 6   Sabin   45  Kathmandu

# %%
# iloc loc

# %%
df.iloc[2:5]
# Out:
#      name  age        add
# sn
# 3    Hari   67  Bhaktapur
# 4    Sita   45      Jhapa
# 5   Nabin   34  Kathmandu

# %%
df.loc[2:5]
# Out:
#      name  age        add
# sn
# 2   Shyam   56   Lalitpur
# 3    Hari   67  Bhaktapur
# 4    Sita   45      Jhapa
# 5   Nabin   34  Kathmandu

# %%
import pandas as pd
df = pd.read_csv('new_data.csv',index_col = 'name')
df.loc['Shyam':'Nabin']
# Out:
#        sn  age        add
# name
# Shyam   2   56   Lalitpur
# Hari    3   67  Bhaktapur
# Sita    4   45      Jhapa
# Nabin   5   34  Kathmandu

# %%
import pandas as pd
df = pd.read_csv('new_data.csv',index_col = 'sn')
df['add']
# Out:
# sn
# 1    Kathmandu
# 2     Lalitpur
# 3    Bhaktapur
# 4        Jhapa
# 5    Kathmandu
# 6    Kathmandu
# Name: add, dtype: object

# %%
df[df['add'] == 'Kathmandu']
# Out:
#      name  age        add
# sn
# 1     Ram   45  Kathmandu
# 5   Nabin   34  Kathmandu
# 6   Sabin   45  Kathmandu

# %%
df[(df['add'] == 'Kathmandu') & (df['age'] > 40)]
# Out:
#      name  age        add
# sn
# 1     Ram   45  Kathmandu
# 6   Sabin   45  Kathmandu

# %%
import csv
info = [['name','age','add'],
       ['Ram',45,'Kathmandu'],
       ['Shyam',34,'Bhaktapur'],
       ['Hari',67,'Lalitpur']]
file = open('list_data.csv','w')
x = csv.writer(file)
x.writerows(info)
file.close()

# %%
import pandas as pd
df = pd.read_csv('list_data.csv')
df
# Out:
#     name  age        add
# 0    Ram   45  Kathmandu
# 1  Shyam   34  Bhaktapur
# 2   Hari   67   Lalitpur

# %%
import csv
with open('list_data.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        print(row)
# Out:
# {'name': 'Ram', 'age': '45', 'add': 'Kathmandu'}
# {'name': 'Shyam', 'age': '34', 'add': 'Bhaktapur'}
# {'name': 'Hari', 'age': '67', 'add': 'Lalitpur'}

# %%
import csv
data = [{'name': 'Ram', 'age': '45', 'add': 'Kathmandu'},
    {'name': 'Shyam', 'age': '34', 'add': 'Bhaktapur'},
    {'name': 'Hari', 'age': '67', 'add': 'Lalitpur'}]
c = ['name','age','add']

with open("data.csv", 'w') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=c)
    writer.writeheader()
    writer.writerows(data)

# %%
df = pd.read_csv('data.csv')
df
# Out:
#     name  age        add
# 0    Ram   45  Kathmandu
# 1  Shyam   34  Bhaktapur
# 2   Hari   67   Lalitpur

# %%
import pandas as pd
data = {'name':['Ram','Shyam','Hari'],
       'age':[34,56,78],
       'add':['Kathmandu','Bhaktapur','Lalitpur']}

df = pd.DataFrame(data)
df.to_csv('dataframe.csv')
df
# Out:
#     name  age        add
# 0    Ram   34  Kathmandu
# 1  Shyam   56  Bhaktapur
# 2   Hari   78   Lalitpur

# %%
df = pd.read_csv('dataframe.csv',usecols = ['name','age','add'])
df
# Out:
#     name  age        add
# 0    Ram   34  Kathmandu
# 1  Shyam   56  Bhaktapur
# 2   Hari   78   Lalitpur

# %%
import pandas as pd
data1 = {'name':['Ram','Shyam','Hari'],
       'age':[34,56,78],
       'add':['Kathmandu','Bhaktapur','Lalitpur']}

data2 = {'name':['Ram','Shyam','Hari'],
       'age':[34,56,78],
       'add':['Kathmandu','Bhaktapur','Lalitpur']}

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)
df = pd.concat([df1,df2])
df
# Out:
#     name  age        add
# 0    Ram   34  Kathmandu
# 1  Shyam   56  Bhaktapur
# 2   Hari   78   Lalitpur
# 0    Ram   34  Kathmandu
# 1  Shyam   56  Bhaktapur
# 2   Hari   78   Lalitpur
